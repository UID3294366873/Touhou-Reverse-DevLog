# %% [markdown]
# 问题命令：`@transition`
#
# 实际处理时是按照以下顺序：
# - 播放转出效果
# - 切换背景图片
# - 播放转出效果
#
# 使用`@transition`命令会跳过中间的背景图片切换
#
# 思考：该命令有使用场景吗？（有存在的必要吗？）
#
# 解决方案：
# - 若有存在的必要，则保留，但是要将转入转出分别设置参数
# - 若无存在必要（即只在切换场景的时候用到），则删去，在使用`@background`的时候作为参数`transition`使用

# %% [markdown]
# 测试：
# 将所有操作符替换成中文输入法对应的操作符，减少中英文反复切换
