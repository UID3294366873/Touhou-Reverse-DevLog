# %% [markdown]
# 为了剧情脚本设计的方便，
# - 可以仿照或者参考renpy设计剧情脚本
# - 采用顺序的结构
# - 并用文件名（？）作为一块剧情的标记
# - 剧情跳转采用更换所使用的剧情文件
#
# ---
# - 用树状结构组织与预加载剧情脚本文件（json？）
# - 文件存储上要不要采用嵌套存储？
#
# ---
# - 一个main脚本文件作为主要运行脚本
# - 在main脚本文件中可以跳转到其他脚本，其他脚本执行完毕跳转回到main主执行脚本
#
# ---
# - 脚本内部可以使用特定参数，来控制一些表达效果
# - 例如文本中采用类html格式控制文本动画，或是BBcode
# - 可以采用调用函数的方式，并填入参数，来控制某些转场，震动效果
#
# ---
# - 整体参考renpy

# %% [markdown]
# ---
# - 使用json是否可行？
# - 剧情脚本转json，json作为运行时读取文件存储
